# %%
pip install --upgrade ultralytics

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo12n.pt")

# Train the model with adjusted parameters
train_results = model.train(
    data="C:/Users/ASUS/Desktop/Kahve_fotolari/dataset/data.yaml",
    epochs=30,  # Reduced number of epochs to avoid overfitting
    imgsz=640,
    batch=16,
    optimizer='AdamW',
    lr0=0.0001,  # Lower initial learning rate
    weight_decay=0.0007,  # Increased weight decay for stronger regularization
    patience=10,  # Reduced patience for early stopping
    warmup_epochs=3,
    augment=True,
    mosaic=0.8,  # Mozaik artırmayı azalt
    mixup=0.1,  # Mixup artırmayı azalt
    fliplr=0.5,
    scale=0.2,
    translate=0.1,
    dropout=0.3,  # Increased dropout for regularization
    freeze=10,  # Keep some layers frozen to reduce overfitting
)

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo12n.pt")

# Train the model
train_results = model.train(
    data="C:/Users/ASUS/Desktop/Kahve_fotolari/dataset/data.yaml",  # path to dataset YAML
    epochs=5,  # number of training epochs
    imgsz=640,  # training image size
    device=0,  # device to run on, i.e. device=0 or device=0,1,2,3 or device=cpu
)

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("runs/detect/train16/weights/best.pt")

# Perform object detection on an image
results = model("C:/Users/ASUS/Desktop/Kahve_fotolari/testfotoları/images (1).jpg", save=True)
results[0].show()
